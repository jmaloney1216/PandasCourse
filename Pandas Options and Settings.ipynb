#
# [1000 rows x 50 columns]

# %%
pd.options.display.max_columns = 4

# %%
df
# Out:
#      0   1  ...  48  49
# 0    20   8 ...  11  36
# 1    28   5 ...  26  49
# 2    62  96 ...   4  38
# 3    99   0 ...  84  24
# 4    62  74 ...  83  63
# 5    97  90 ...  61  91
# 6    21  27 ...  27  26
# 7    15  51 ...  72  26
# 8     2   6 ...  97  24
# ..   ..  .. ...  ..  ..
# 991  25  97 ...  93  56
# 992   9  74 ...  21  80
# 993   9  20 ...  18  38
# 994  31  96 ...  61  70
# 995  45  90 ...  72  34
# 996  17  83 ...  61   4
# 997  47  47 ...  58  76
# 998  16  18 ...  51  84
# 999  29  51 ...  28  84
#
# [1000 rows x 50 columns]

# %% [markdown]
# # Changing pandas Options with Methods

# %%
pd.get_option('max_rows')
# Out:
# 18

# %%
pd.get_option('max_columns')
# Out:
# 4

# %%
pd.set_option('max_rows', 25)

# %%
df
# Out:
#      0   1  ...  48  49
# 0    20   8 ...  11  36
# 1    28   5 ...  26  49
# 2    62  96 ...   4  38
# 3    99   0 ...  84  24
# 4    62  74 ...  83  63
# 5    97  90 ...  61  91
# 6    21  27 ...  27  26
# 7    15  51 ...  72  26
# 8     2   6 ...  97  24
# 9    10  21 ...  28  24
# 10    9  90 ...  62  32
# 11   33  30 ...  42  51
# ..   ..  .. ...  ..  ..
# 988  12  11 ...  21  47
# 989  73  73 ...  72  94
# 990  62  26 ...  58  80
# 991  25  97 ...  93  56
# 992   9  74 ...  21  80
# 993   9  20 ...  18  38
# 994  31  96 ...  61  70
# 995  45  90 ...  72  34
# 996  17  83 ...  61   4
# 997  47  47 ...  58  76
# 998  16  18 ...  51  84
# 999  29  51 ...  28  84
#
# [1000 rows x 50 columns]

# %%
pd.options.display.max_rows
# Out:
# 25

# %%
pd.reset_option('max_rows')

# %%
pd.get_option('max_rows')
# Out:
# 60

# %%
pd.reset_option('max_columns')

# %%
pd.describe_option('max_columns')
# Out:
# display.max_columns : int
#     If max_cols is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the width of the terminal and print a truncated object which fits
#     the screen width. The IPython notebook, IPython qtconsole, or IDLE
#     do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 20] [currently: 20]

# %% [markdown]
# # The precision Option

# %%
df = pd.DataFrame(np.random.randn(5,5))
df
# Out:
#           0         1         2         3         4
# 0  0.068465 -0.708371 -0.993106 -1.987176  0.719035
# 1  1.511722  1.149781 -1.022598  0.815607 -0.536314
# 2 -0.005217  0.090895  1.680196  1.229367 -0.324667
# 3  0.945110  0.431329 -1.363734  1.637921 -0.465048
# 4 -0.709645 -1.409849 -1.677123  0.590122  0.221756

# %%
pd.get_option('precision')
# Out:
# 6

# %%
pd.set_option('precision', 2)

# %%
df
# Out:
#           0     1     2     3     4
# 0  6.85e-02 -0.71 -0.99 -1.99  0.72
# 1  1.51e+00  1.15 -1.02  0.82 -0.54
# 2 -5.22e-03  0.09  1.68  1.23 -0.32
# 3  9.45e-01  0.43 -1.36  1.64 -0.47
# 4 -7.10e-01 -1.41 -1.68  0.59  0.22

# %%
pd.reset_option('precision')

# %%
df
# Out:
#           0         1         2         3         4
# 0  0.068465 -0.708371 -0.993106 -1.987176  0.719035
# 1  1.511722  1.149781 -1.022598  0.815607 -0.536314
# 2 -0.005217  0.090895  1.680196  1.229367 -0.324667
# 3  0.945110  0.431329 -1.363734  1.637921 -0.465048
# 4 -0.709645 -1.409849 -1.677123  0.590122  0.221756
